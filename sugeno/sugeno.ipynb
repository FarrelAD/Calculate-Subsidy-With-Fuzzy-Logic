# %% [markdown]
# <a href="https://colab.research.google.com/github/FarrelAD/Calculate-Subsidy-With-Fuzzy-Logic/blob/main/sugeno/sugeno.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install Required Library

# %%
# !pip install scikit-fuzzy
# Out:
# Requirement already satisfied: scikit-fuzzy in /usr/local/lib/python3.11/dist-packages (0.5.0)

# %%
import numpy as np
import skfuzzy as fuzz
import skfuzzy.control as ctrl
import matplotlib.pyplot as plt

# %% [markdown]
# # Define Fuzzy Variables

# %%
land_area = ctrl.Antecedent(np.arange(0, 4, 0.01), 'land_area')
rice_production = ctrl.Antecedent(np.arange(0, 1.6, 0.01), 'rice_production')
irrigation = ctrl.Antecedent(np.arange(1500, 18500, 100), 'irrigation')
subsidy = ctrl.Consequent(np.arange(1, 8, 0.1), 'subsidy')

# %% [markdown]
# # Define Fuzzy Membership Functions

# %%
land_area['very small'] = fuzz.trimf(land_area.universe, [0, 0.5, 1])
land_area['small'] = fuzz.trimf(land_area.universe, [0.5, 1, 1.5])
land_area['medium'] = fuzz.trimf(land_area.universe, [1, 1.5, 2])
land_area['large'] = fuzz.trimf(land_area.universe, [1.5, 2, 2.5])
land_area['very large'] = fuzz.trimf(land_area.universe, [2, 2.5, 3])

rice_production['very low'] = fuzz.trimf(rice_production.universe, [0, 0.25, 0.5])
rice_production['low'] = fuzz.trimf(rice_production.universe, [0.25, 0.5, 0.75])
rice_production['medium'] = fuzz.trimf(rice_production.universe, [0.5, 0.75, 1])
rice_production['high'] = fuzz.trimf(rice_production.universe, [0.75, 1, 1.25])
rice_production['very high'] = fuzz.trimf(rice_production.universe, [1, 1.25, 1.5])

irrigation['very low'] = fuzz.trimf(irrigation.universe, [1500, 4250, 7000])
irrigation['low'] = fuzz.trimf(irrigation.universe, [4250, 7000, 9750])
irrigation['medium'] = fuzz.trimf(irrigation.universe, [7000, 9750, 12500])
irrigation['high'] = fuzz.trimf(irrigation.universe, [9750, 12500, 15250])
irrigation['very high'] = fuzz.trimf(irrigation.universe, [12500, 15250, 18000])

subsidy['very low'] = fuzz.trimf(subsidy.universe, [1, 2, 3])
subsidy['low'] = fuzz.trimf(subsidy.universe, [2, 3, 4])
subsidy['medium'] = fuzz.trimf(subsidy.universe, [3, 4, 5])
subsidy['high'] = fuzz.trimf(subsidy.universe, [4, 5, 6])
subsidy['very high'] = fuzz.trimf(subsidy.universe, [5, 6, 7])

# %%
land_area.view()
rice_production.view()
irrigation.view()
subsidy.view()

# %% [markdown]
# # Define Fuzzy Rules
